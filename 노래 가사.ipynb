# %%
import requests
import requests as req
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import time

# %%
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from konlpy.tag import Kkma, Komoran, Okt, Hannanum

# %%
import pandas as pd
import numpy as np

# %%
def song_num():
    url = input()
    driver = webdriver.Chrome()
    driver.get(url)
    
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    num = soup.select('#conts > div.section_contin > div.page_header > h5 > span')[0].text
    num = num.replace('(','')
    num = num.replace(')','')
    num = int(num)
    return num

# %%
def lyrics(url, num):
    url = input()
    driver = webdriver.Chrome()
    driver.implicitly_wait(10)

    driver.get(url)        
    source = driver.page_source
    
    for lst in driver.find_elements_by_css_selector('#frm > div > table > tbody > tr'):
        path = 'td:nth-child(4) > div > a'
        scroll_button = '#lyricArea > button'
        lst.find_element_by_css_selector(path).click()
#             if driver.find_elements_by_css_selector(scroll_button):
#                 driver.find_elements_by_css_selector(scroll_button)[0].click()

#                 html = driver.page_source
#                 soup = BeautifulSoup(html, 'html.parser')
#                 tell = soup.select('#d_video_summary')[0].text
#                 print(re.compile('[ㄱ-ㅎ가-힣]+').findall(tell))
#                 print('='*150)
        driver.back()
#                     time.sleep(1) 
#                 except:
#                     driver.back()

# %%
num = song_num()
# Out:
# https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=499283495

# %%
lyrics('url',num)
# Out:
# https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=499283495
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_14992/655366989.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for lst in driver.find_elements_by_css_selector('#frm > div > table > tbody > tr'):
# C:\Users\bitcamp\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:484: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14992/3384392047.py in <module>
# ----> 1 lyrics('url',num)
#
# ~\AppData\Local\Temp/ipykernel_14992/655366989.py in lyrics(url, num)
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=506712136')
driver.implicitly_wait(2)

# %%
path = '#frm > div > table > tbody > tr'
num = len(driver.find_elements_by_css_selector(path))
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_4152/167090936.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   num = len(driver.find_elements_by_css_selector(path))

# %%
for ind in range(1,1+num): 
    driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
    scroll_button = '#lyricArea > button'

#     print(driver.find_elements_by_css_selector(scroll_button))
    if driver.find_elements_by_css_selector(scroll_button):
        driver.find_elements_by_css_selector(scroll_button)[0].click()
        print('click')
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        tell = soup.select('#d_video_summary')[0].text
        print(re.compile('[ㄱ-ㅎ가-힣]+').findall(tell))
        print('='*150)
    else:
        pass
    driver.back()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_14992/430193963.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_14992/430193963.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   if driver.find_elements_by_css_selector(scroll_button):
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_14992/430193963.py:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   driver.find_elements_by_css_selector(scroll_button)[0].click()
# click
# ...

# %% [markdown]
# # ★마스터 코드★

# %%
def song_num():
    url = input()
    driver = webdriver.Chrome()
    driver.get(url)
    
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    num = soup.select('#conts > div.section_contin > div.page_header > h5 > span')[0].text
    num = num.replace('(','')
    num = num.replace(')','')
    num = int(num)
    return num

# %%
num = song_num()
print(num)

if num > 50:
    print('첫 번째 셀을 돌리시오')
else:
    print('두 번째 셀을 돌리시오')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/3728764874.py in <module>
# ----> 1 num = song_num()
#       2 num
#
# ~\AppData\Local\Temp/ipykernel_18540/957108459.py in song_num()
#       1 def song_num():
# ----> 2     url = input()
#       3     driver = webdriver.Chrome()
#       4     driver.get(url)
#       5
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1005                 "raw_input was called, but this frontend does not support input requests."
#    1006             )
# -> 1007         return self._input_request(
#    1008             str(prompt),
#    1009             self._parent_ident["shell"],
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
for i in range(1,num,50):
    if i:
        url = ''
        url = url.format(i)
        driver = webdriver.Chrome()
        driver.get(url)
        
        driver.find_element_by_css_selector('span.menu_bg.menu09').click()
        time.sleep(1)
        driver.find_element_by_css_selector('div.wrap_btn').click()
        time.sleep(2)
        print(driver.window_handles)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        driver.find_element_by_id('id_email_2').send_keys('wjddus531@gmail.com')
        driver.find_element_by_id('id_password_3').send_keys('dkpark70')
        driver.find_element_by_css_selector('#login-form > fieldset > div.wrap_btn > button.btn_g.btn_confirm.submit').click()
        time.sleep(2)
        print(driver.window_handles)
        driver.switch_to.window(driver.window_handles[0])
        driver.get(url)
        
        lyrics = []

        for ind in range(1,50):
            try:
                driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
                scroll_button = '#lyricArea > button'

                if driver.find_elements_by_css_selector(scroll_button):
                    driver.find_elements_by_css_selector(scroll_button)[0].click()
#                     print('click')
                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    tell = soup.select('#d_video_summary')[0].text
                    print(tell)
                    print('='*130)
                    lyrics.append(tell)
#                     print(re.compile('[ㄱ-ㅎ가-힣]+').findall(tell))
                    
                else:
                    pass
                driver.back()
            except:
                break
# Out:
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/315360036.py:10: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/315360036.py:13: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   if driver.find_elements_by_css_selector(scroll_button):
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/315360036.py:14: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_elements_by_css_selector(scroll_button)[0].click()
# ...

# %%
url = ''
url = url.format(i)
driver = webdriver.Chrome()
driver.get(url)

driver.find_element_by_css_selector('span.menu_bg.menu09').click()
time.sleep(1)
driver.find_element_by_css_selector('div.wrap_btn').click()
time.sleep(2)
print(driver.window_handles)
driver.switch_to.window(driver.window_handles[1])
time.sleep(1)
driver.find_element_by_id('id_email_2').send_keys('wjddus531@gmail.com')
driver.find_element_by_id('id_password_3').send_keys('dkpark70')
driver.find_element_by_css_selector('#login-form > fieldset > div.wrap_btn > button.btn_g.btn_confirm.submit').click()
time.sleep(2)
print(driver.window_handles)
driver.switch_to.window(driver.window_handles[0])
driver.get(url)

lyrics = []

for ind in range(1,50):
            try:
                driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
                scroll_button = '#lyricArea > button'

                if driver.find_elements_by_css_selector(scroll_button):
                    driver.find_elements_by_css_selector(scroll_button)[0].click()
#                     print('click')
                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    tell = soup.select('#d_video_summary')[0].text
#                     ly = re.compile('[ㄱ-ㅎ가-힣]+').findall(tell)
                    print(tell)
                    print('='*130)
                    lyrics.append(tell)
                else:
                    pass
                driver.back()
            except:
                break

# %% [markdown]
# # 몽환

# %%
num = song_num()
print(num)

if num > 50:
    print('첫 번째 셀을 돌리시오')
else:
    print('두 번째 셀을 돌리시오')
# Out:
# https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=427968315
# 54
# 첫 번째 셀을 돌리시오

# %%
driver = webdriver.Chrome()
url = 'https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=427968315#params%5BplylstSeq%5D=427968315&po=pageObj&startIndex=1'
driver.get(url)

driver.find_element_by_css_selector('span.menu_bg.menu09').click()
time.sleep(1)
driver.find_element_by_css_selector('div.wrap_btn').click()
time.sleep(2)
# print(driver.window_handles)
driver.switch_to.window(driver.window_handles[1])
time.sleep(1)
driver.find_element_by_id('id_email_2').send_keys('wjddus531@gmail.com')
driver.find_element_by_id('id_password_3').send_keys('dkpark70')
driver.find_element_by_css_selector('#login-form > fieldset > div.wrap_btn > button.btn_g.btn_confirm.submit').click()
time.sleep(2)
# print(driver.window_handles)
driver.switch_to.window(driver.window_handles[0])
driver.get(url)


for i in range(1,num,50):
    if i:
        url = 'https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=427968315#params%5BplylstSeq%5D=427968315&po=pageObj&startIndex={}'
        url = url.format(i)
        driver = webdriver.Chrome()
        driver.get(url)
        
        lyrics = []

        for ind in range(1,50):
            try:
                driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
                scroll_button = '#lyricArea > button'

                if driver.find_elements_by_css_selector(scroll_button):
                    driver.find_elements_by_css_selector(scroll_button)[0].click()
#                     print('click')
                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    tell = soup.select('#d_video_summary')[0].text
                    print(tell)
                    print('='*130)
                    lyrics.append(tell)
#                     print(re.compile('[ㄱ-ㅎ가-힣]+').findall(tell))
                    
                else:
                    pass
                driver.back()
            except:
                break
# Out:
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/3798060256.py:28: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('span.menu_bg.menu09').click()
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/3798060256.py:30: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('div.wrap_btn').click()
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/3798060256.py:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('id_email_2').send_keys('wjddus531@gmail.com')
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/3798060256.py:36: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
pd.DataFrame(lyrics, columns=['가사'])
# Out:
#                                                   가사
# 0  \n\t\t\t\t\t\t\t여기에도 저기에도나 있을 곳 없다가까워도 먼 우리 사이...
# 1  \n\t\t\t\t\t\t\t네 눈에 눈물이 고일 때 내 눈은 차갑게 말하네 지펴도...
# 2  고통의 눈물은 흐르질 못하고 애원의 말들은 입가를 맴돌고 구원의 손길은 자취를 감추...

# %% [markdown]
# # test

# %%
driver = webdriver.Chrome()
url = 'https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=427968315#params%5BplylstSeq%5D=427968315&po=pageObj&startIndex=1'
driver.get(url)

driver.find_element_by_css_selector('span.menu_bg.menu09').click()
time.sleep(1)
driver.find_element_by_css_selector('div.wrap_btn').click()
time.sleep(2)
# print(driver.window_handles)
driver.switch_to.window(driver.window_handles[1])
time.sleep(1)
driver.find_element_by_id('id_email_2').send_keys('wjddus531@gmail.com')
driver.find_element_by_id('id_password_3').send_keys('dkpark70')
driver.find_element_by_css_selector('#login-form > fieldset > div.wrap_btn > button.btn_g.btn_confirm.submit').click()
time.sleep(2)
# print(driver.window_handles)
driver.switch_to.window(driver.window_handles[0])
driver.get(url)


for i in range(1,num,50):
    if i:
        url = 'https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=427968315#params%5BplylstSeq%5D=427968315&po=pageObj&startIndex={}'
        url = url.format(i)
        driver = webdriver.Chrome()
        driver.get(url)
        
        lyrics = []

        for ind in range(1,50):
            try:
                driver.find_element_by_css_selector(f'#frm > div > table > tbody > tr:nth-child({ind}) > td:nth-child(4) > div > a').click()
                scroll_button = '#lyricArea > button'

                if driver.find_elements_by_css_selector(scroll_button):
                    driver.find_elements_by_css_selector(scroll_button)[0].click()
#                     print('click')
                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    tell = soup.select('#d_video_summary')[0].text
                    print(tell)
                    print('='*130)
                    lyrics.append(tell)
#                     print(re.compile('[ㄱ-ㅎ가-힣]+').findall(tell))
                    
                else:
                    pass
                driver.back()
            except:
                break
# Out:
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/4124936995.py:5: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('span.menu_bg.menu09').click()
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/4124936995.py:7: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('div.wrap_btn').click()
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/4124936995.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('id_email_2').send_keys('wjddus531@gmail.com')
# C:\Users\wjddu\AppData\Local\Temp/ipykernel_18540/4124936995.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
soup.select('#d_video_summary > div')[0].text
# Out:
# '아티스트 임영웅 첫 정규 앨범 [IM HERO] 선공개 싱글  ‘우리들의 블루스’  희망과 위로가 되어 주세요 우리 모두 서로에게…   Credits  Lyrics by 지훈 Composed by 이승주, 최인환 Arranged by 이승주, 최인환  Drum by 은주현 Bass by 이승주 Guitar by 박신원 Keyboard by 최인환 String Arranged by 최인환 String Performed by 융스트링 Background Vocals by 배진영  Recorded by 김현곤 @Doobdoob Studio  장수남 @Velvet Studio  Mixed by 김현곤 @Doobdoob Studio Mastered by 권남우@821Sound Mastering '

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=499283495')

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html class="narrow-screen" lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>DJ플레이리스트 정보&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="살아있는 우리 모두 행복하라! tvN 우리들의 블루스 OST &amp; BGM" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/svc/user_images/plylst/2022/04/208/94/499283495_org.jpg?tm=20220419091250/melon/resize/500/quality/80/optimize" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# ...

# %%
num = soup.select('#conts > div.section_contin > div.page_header > h5 > span')[0].text
num = num.replace('(','')
num = num.replace(')','')
num = int(num)

# %%
re.compile('[ㄱ-ㅎ가-힣]+').findall(tell)
# Out:
# []
